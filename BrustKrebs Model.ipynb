# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
file='../data/Kursmaterialien/data/Krebs/cancer.csv'
df=pd.read_csv(file)
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df["outcome"]=df["diagnosis"]=="M"

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
print(len(df[df["diagnosis"]=="B"]))

df[df["diagnosis"]=="B"]
df[df["radius_mean"]>10]
# Out:
# 357
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 563    926125         M        20.92         25.09          143.00     1347.0
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
#
# ...

# %%
from sklearn.model_selection import GridSearchCV,train_test_split,RepeatedKFold
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
X=df[["radius_mean","texture_mean","perimeter_mean"]]
y=df["outcome"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.80,
            random_state=101)
# model=SVC(kernel="rbf",gamma="auto",max_iter=100)
# model=LinearRegression(normalize=True)
# model=KNeighborsClassifier(algorithm='ball_tree',n_jobs=5)
# model=DecisionTreeClassifier(max_depth=10,)

# clf=GridSearchCV(DecisionTreeClassifier(),param_grid={
#     "max_depth":[3,5,10,15,20,25],
#     "min_samples_leaf":[1,3,5,10,15]
    
# },cv=RepeatedKFold())

# clf=GridSearchCV(LogisticRegression(),param_grid={
#     "max_iter":[1000]
    
# },cv=RepeatedKFold())
# clf=GridSearchCV(SVC(),param_grid={
#     'kernel':['rbf'],
#     'gamma':[0.01,0.1,1,10],
#     'C':[0.01,0.1,0.5,1,5,10]
    
# },cv=RepeatedKFold(),n_jobs=2)
clf=make_pipeline(StandardScaler(),SVC(gamma='auto'))

try:
     clf.fit(X_train,y_train)
       
except Exception as e:
    print(e.args)

# %%
# plot_tree(clf,
# feature_names=["radius_mean","texture_mean","perimeter_mean"],
#           class_names=["kein Krebs","Krebs"]
         
         
#          )

# plt.show()

# %%
# clf.best_score_

# %%
print(f"{round(clf.score(X_train,y_train),2)*100}%")
print(f"{round(clf.score(X_test,y_test),3)*100}%")
# Out:
# 91.0%
# 90.4%

# %%
radius=input("geben Sie Radius des Tumors ein: ")
textur=input("geben Sie die Texturgröße des Tumors ein: ")
Umfang=input("geben Sie die Umfang des Tumors ein: ")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 radius=input("geben Sie Radius des Tumors ein: ")
#       2 textur=input("geben Sie die Texturgröße des Tumors ein: ")
#       3 Umfang=input("geben Sie die Umfang des Tumors ein: ")
#
# File ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# ...

# %%
# clf.predict([[10.05,30.31,140],[10,30,10]])

results=pd.DataFrame([
    [radius,textur,Umfang]
],columns=["radius_mean","texture_mean","perimeter_mean"]
                   
                   )

# %%
results
# Out:
#   radius_mean texture_mean perimeter_mean
# 0       10.05        30.31            140

# %%
prediction=clf.predict(results)

# %%
for i in prediction:
    if i ==True:
        print(f"""Durch die angebenen Werte haben Sie mit ca. 90% 
            Wahrscheinlichkeit Brustkrebs{results[:1]}
              """)
    else:
        print("Die Angebenen Werte deuten das Sie kein Brustkrebs haben")
# Out:
# Durch die angebenen Werte haben Sie mit ca. 90%
#             Wahrscheinlichkeit Brustkrebs  radius_mean texture_mean perimeter_mean
# 0       10.05        30.31            140
